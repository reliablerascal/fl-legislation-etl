# %% [markdown]
# # Review Jacksonville City Council data available via Legistar API
# 6/27/24 RR
# This is my second pass at reviewing Jacksonville's LegiStar City Council data
# this time with an intent to see how I can align its data model with Jacksonville Tributary's voting patterns dashboard
#
# My goal for this notebook is to identify data tables comparable to <a href="https://docs.google.com/spreadsheets/d/1b31rNAorqwDvkmt0IZqL1rWDfBNnI5fwEfhm3y4oYbM/edit?gid=578455680#gid=578455680">LegiScan data dictionary</a> for legislator_sessions, legislator_votes, roll_calls, and bills
#
# After this analysis would be to retrieve and store this data, then transform to align with LegiScan data

# %% [markdown]
# ### Key Terminology for Legistar Data (from prior notebook)
# <strong>Matters</strong> are legislative item that could include ordinances, resolutions, appointments, or other legislative proposals. Records for matters track the entire lifecycle of a legislative proposal, from introduction to action.<br>
# <strong>EventItems</strong> are specific instances of matters being discussed at a meeting

# %% [markdown]
# ### Next Steps for This Analysis
# <ul>
#     <li>Review 4x dataframes again against API call options</li>
#     <li></li>
#
# </ul>

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Related Documentation
# <ul>
# <li><a href="https://webapi.legistar.com/Help">API calls</a>
# <li><a href="https://webapi.legistar.com/Home/Examples">Examples</a>
# <li><a href="https://www.odata.org/documentation/odata-version-3-0/url-conventions/">URL params</a>
# </ul>

# %% [markdown]
# # Find Legislators
# These are placeholders, not legislators. Hmm...

# %%
url = "https://webapi.legistar.com/v1/jaxcityc/persons"
response = requests.get(url)
data = response.json()
df_legislators=pd.DataFrame(data)
df_legislators
# Out:
#      PersonId                            PersonGuid    PersonLastModifiedUtc  \
# 0         120  F908B30C-8FFD-4901-876E-4515B66F77C6    2014-05-24T04:19:34.8
# 1         145  74646384-CDC4-497D-84AB-CB1215FD7BED    2014-05-24T04:19:34.8
# 2         169  7BC464BF-1335-4981-8B7A-AE0FBFF54B98    2014-05-24T04:19:34.8
# 3         170  C4B6BB7D-C493-408C-A9B7-8CE6E2F0D499    2014-05-24T04:19:34.8
# 4         171  DDDDEC13-B831-4BA5-8D4E-FE55BCFB67AE    2014-05-24T04:19:34.8
# ..        ...                                   ...                      ...
# 192       373  30A88267-30E1-4E65-9E85-A71B0EC68E05  2023-11-27T19:05:37.877
# 193       374  E7D5B6BB-42F8-43E0-8D7C-AD55878EB757  2023-11-27T19:06:06.133
# 194       375  456D7DAD-F032-4BCD-BBA9-736F3F810F02   2024-02-16T14:14:31.95
# 195       376  76B0E57F-94A4-4DA8-8373-3CF874785362  2024-02-16T14:14:57.877
# 196       378  8D587A92-FFBE-4E77-8774-693EB83224A2   2024-03-07T13:23:37.91
#
#     PersonRowVersion PersonFirstName PersonLastName        PersonFullName  \
# 0       AAAAAAAQhGQ=                        Daystar               Daystar
# 1       AAAAAAAMjVE=            View           Only             View Only
# 2       AAAAAAAMjVI=        Legistar         System       Legistar System
# 3       AAAAAACGiuE=        Granicus           User         Granicus User
# 4       AAAAAAAPyNg=          System  Administrator  System Administrator
# ..               ...             ...            ...                   ...
# 192     AAAAAAEFOUY=           Ivana         Gavric          Ivana Gavric
# 193     AAAAAAEFOVI=         Vanessa          Galan         Vanessa Galan
# 194     AAAAAAETVLo=           Kiyan        Michael    Rep. Kiyan Michael
# 195     AAAAAAETVLU=            Jack          Meeks            Jack Meeks
# 196     AAAAAAEYRAU=         Alexis         Zellner       Alexis  Zellner
#
#      PersonActiveFlag  PersonCanViewFlag  PersonUsedSponsorFlag  ...  \
# 0                   1                  0                      0  ...
# 1                   1                  0                      0  ...
# 2                   1                  0                      0  ...
# 3                   0                  1                      0  ...
# 4                   1                  1                      0  ...
# ..                ...                ...                    ...  ...
# 192                 1                  1                      0  ...
# 193                 1                  1                      0  ...
# 194                 1                  1                      0  ...
# 195                 1                  1                      0  ...
# 196                 1                  1                      0  ...
#
#                PersonEmail PersonWWW PersonAddress2 PersonCity2 PersonState2  \
# 0    Legistar@granicus.com
# 1                                              None        None         None
# 2                     None      None           None        None         None
# 3
# 4
# ..                     ...       ...            ...         ...          ...
# 192
# 193
# 194
# 195
# 196
#
#     PersonZip2 PersonPhone2 PersonFax2 PersonEmail2 PersonWWW2
# 0
# 1         None         None       None         None       None
# 2         None         None       None         None       None
# 3
# 4
# ..         ...          ...        ...          ...        ...
# 192
# 193
# 194
# 195
# 196
#
# [197 rows x 26 columns]

# %% [markdown]
# # Find Roll Calls
# This data may not be directly accessible. API requests seem to be nested under event items (which may in turn require stepping through events).

# %%
url = "https://webapi.legistar.com/v1/jaxcityc/RollCalls"
response = requests.get(url)
data = response.json()
df_roll_calls=pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[13], line 3
#       1 url = "https://webapi.legistar.com/v1/jaxcityc/RollCalls"
#       2 response = requests.get(url)
# ----> 3 data = response.json()
#       4 df=pd.DataFrame(data)
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # Find Bills
# Need to decide which types of "matters" are worth including in partisan vote analysis, then filter by MatterTypeName

# %%
url = "https://webapi.legistar.com/v1/jaxcityc/Matters"
response = requests.get(url)
data = response.json()
df_bills=pd.DataFrame(data)
df_bills
# Out:
#      MatterId                            MatterGuid    MatterLastModifiedUtc  \
# 0        1122  32DDFD32-6D3D-44B3-800C-CCDF2EC8FA84   2019-10-10T18:24:59.82
# 1        1298  AEF9A6D3-B410-4AAD-8410-AA9D07B97790  2020-08-07T13:48:28.607
# 2        1299  C2F6C217-3436-4DA0-95EC-18BF99BB6C36  2019-10-10T18:53:54.663
# 3        1300  62112730-8D2C-4AB6-BE63-00E80B768BB5   2021-07-21T16:44:27.33
# 4        1301  CA6EC378-00E3-41C0-8803-038474CF96FE   2019-10-10T18:56:45.29
# ..        ...                                   ...                      ...
# 995      2467  4022DB2D-7690-4427-A613-F7438B710012  2020-08-21T14:37:16.633
# 996      2468  8660E009-784A-4607-8D48-C070E9619A91  2022-02-09T19:14:38.167
# 997      2469  24A78F61-F976-48AF-BA8B-E05DBAC55AB9    2020-09-10T20:44:23.8
# 998      2470  F2F07937-7DF4-4834-A49B-047760895367    2020-08-20T21:01:27.8
# 999      2471  D2E314AA-068B-462B-A9B6-99037B3AD5CE  2020-08-07T13:50:35.177
#
#     MatterRowVersion   MatterFile MatterName  \
# 0       AAAAAACQoh0=  2018-0310-W       None
# 1       AAAAAACQnzA=  2019-0307-E       None
# 2       AAAAAAApgeQ=  2019-0308-E       None
# 3       AAAAAACQnzE=  2019-0309-W       None
# 4       AAAAAAApgnk=  2019-0310-E       None
# ..               ...          ...        ...
# 995     AAAAAABOL68=  2020-0376-A       None
# 996     AAAAAACQpIk=  2020-0377-E       None
# 997     AAAAAABRK78=  2020-0378-E       None
# 998     AAAAAABOJGk=  2020-0379-E       None
# 999     AAAAAABLxCs=  2020-0380-E       None
#
#                                            MatterTitle  MatterTypeId  \
# 0    ORD-MC Amend Sec 656.152 (Certification of Use...            53
# 1    ORD Transmitting a Proposed Large Scale FLUM A...            53
# 2    ORD Transmitting a Proposed Large Scale Revisi...            53
# 3    ORD Transmitting a Proposed Large Scale Revisi...            53
# 4    ORD Apv 2019B Series Text Amend to the Capital...            53
# ..                                                 ...           ...
# 995  RESO Apv  Issuance by Jax Housing Finance Auth...            52
# 996  ORD Making Certain Findings & Authorizing: (1)...            53
# 997  ORD Accepting & Approp $8,069,919.30 of Additi...            53
# 998  ORD Making Certain Findings & Approp $1,000,00...            53
# 999  ORD Approp $3,000,000 of Cares Act Grant Fundi...            53
#
#     MatterTypeName  MatterStatusId  ... MatterEXDate5  MatterEXDate6  \
# 0        Ordinance              75  ...          None           None
# 1        Ordinance              96  ...          None           None
# 2        Ordinance              96  ...          None           None
# 3        Ordinance              75  ...          None           None
# 4        Ordinance              96  ...          None           None
# ..             ...             ...  ...           ...            ...
# 995     Resolution              97  ...          None           None
# 996      Ordinance              96  ...          None           None
# 997      Ordinance              96  ...          None           None
# 998      Ordinance              96  ...          None           None
# 999      Ordinance              96  ...          None           None
#
#     MatterEXDate7 MatterEXDate8 MatterEXDate9 MatterEXDate10 MatterAgiloftId  \
# 0            None          None          None           None               0
# 1            None          None          None           None               0
# 2            None          None          None           None               0
# 3            None          None          None           None               0
# 4            None          None          None           None               0
# ..            ...           ...           ...            ...             ...
# 995          None          None          None           None               0
# 996          None          None          None           None               0
# 997          None          None          None           None               0
# 998          None          None          None           None               0
# 999          None          None          None           None               0
#
#     MatterReference MatterRestrictViewViaWeb MatterReports
# 0              None                    False            []
# 1              None                    False            []
# 2              None                    False            []
# 3              None                    False            []
# 4              None                    False            []
# ..              ...                      ...           ...
# 995            None                    False            []
# 996            None                    False            []
# 997            None                    False            []
# 998            None                    False            []
# 999            None                    False            []
#
# [1000 rows x 54 columns]

# %% [markdown]
# # Find Votes
# This data may not be directly accessible. API requests seem to be nested under event items (which may in turn require stepping through events).

# %%
url = "https://webapi.legistar.com/v1/jaxcityc/Votes"
response = requests.get(url)
data = response.json()
df_bills=pd.DataFrame(data)
df_bills
